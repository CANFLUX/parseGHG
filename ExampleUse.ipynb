# %% [markdown]
# # Example Usage
#
# Given a .ghg file, this script can parse all relevant metadata and extract raw data for further processing
#
# ## Inputs
#
# filepath:
#
# * path to GHG filepath
#
# mode:
#
# * 1 - only parse metadata, returned as a nested dictionary
# * 2 - parse metadata **and** dump raw data to time-stamped pandas data frame(s)
#
#
# depth:
#
# * base - default behavior, only parse files in root of GHG, this is sufficient in most use cases
# * full - parse all files, including nested subdirectories, gives access to config files and eddypro files where present

# %% [markdown]
# ## Example 1: Parse all metadata

# %%
import importlib
import parseGHG
import yaml
import time

importlib.reload(parseGHG)

T1 = time.time()
# path to a .ghg file
filepath = r"example_Data\2022-09-04T080000_smart3-00495.ghg"
print('Parsing: ',filepath)
# declare the class instance
pGHG = parseGHG.parseGHG()
# call the parse function (mode = 1, depth='full') to just extract metadata for **all** files
pGHG.parse(filepath,mode=1,depth='full')

print('Time to complete: ',time.time()-T1)
print()

# write these Metadata dict to a human readable yaml format
outName = filepath.split('.')[0]+'.yml'
with open(outName,'w') as outFile:
    print('Saving metadata as: ',outName)
    yaml.dump(pGHG.Metadata,outFile,sort_keys=False)
# Out:
# Parsing:  example_Data\2022-09-04T080000_smart3-00495.ghg
# Time to complete:  0.13328123092651367
#
# Saving metadata as:  example_Data\2022-09-04T080000_smart3-00495.yml

# %% [markdown]
# ## Example 2: Read the essential raw data files
#
# * Raw high frequency data and biomet data (where present)

# %%
importlib.reload(parseGHG)

T1 = time.time()
filepath = r"example_Data\2022-09-04T080000_smart3-00495.ghg"
print('Parsing: ',filepath)
# declare the class instance
pGHG = parseGHG.parseGHG()
# call the parse function (mode = 2) to just extract metadata for just the base files
pGHG.parse(filepath,mode=2,depth='base')
print('Time to complete: ',time.time()-T1)
print()

for name,data in pGHG.Data.items():
    print(name,' file:')
    print()
    print(data.head())
# Out:
# Parsing:  example_Data\2022-09-04T080000_smart3-00495.ghg
# Time to complete:  0.7360353469848633
#
# .data  file:
#
#                         DATAH     Seconds  Nanoseconds  Sequence Number  \
# 2022-09-04 08:00:00.000  DATA  1662300000            0       2147483647
# 2022-09-04 08:00:00.050  DATA  1662300000     50000000       2147483647
# 2022-09-04 08:00:00.100  DATA  1662300000    100000000       2147483647
# 2022-09-04 08:00:00.150  DATA  1662300000    150000000       2147483647
# 2022-09-04 08:00:00.200  DATA  1662300000    200000000       2147483647
#
#                          Diagnostic Value  Diagnostic Value 2  \
# 2022-09-04 08:00:00.000               254                   1
# 2022-09-04 08:00:00.050               254                   1
# 2022-09-04 08:00:00.100               254                   1
# 2022-09-04 08:00:00.150               254                   1
# 2022-09-04 08:00:00.200               254                   1
#
#                          DS Diagnostic Value        Date          Time  \
# 2022-09-04 08:00:00.000                    0  2022-09-04  08:00:00:000
# 2022-09-04 08:00:00.050                    0  2022-09-04  08:00:00:050
# 2022-09-04 08:00:00.100                    0  2022-09-04  08:00:00:100
# 2022-09-04 08:00:00.150                    0  2022-09-04  08:00:00:150
# 2022-09-04 08:00:00.200                    0  2022-09-04  08:00:00:200
#
#                          CO2 Absorptance  ...  CH4 (mmol/m^3)  \
# 2022-09-04 08:00:00.000         0.120011  ...        0.081785
# 2022-09-04 08:00:00.050         0.120036  ...        0.081443
# 2022-09-04 08:00:00.100         0.120004  ...        0.081513
# 2022-09-04 08:00:00.150         0.120136  ...        0.081560
# 2022-09-04 08:00:00.200         0.120065  ...        0.081459
#
#                          CH4 Temperature  CH4 Pressure  CH4 Signal Strength  \
# 2022-09-04 08:00:00.000          15.1098       94.6574              46.7108
# 2022-09-04 08:00:00.050          15.1083       94.6598              46.8168
# 2022-09-04 08:00:00.100          15.1042       94.6598              46.3857
# 2022-09-04 08:00:00.150          15.1147       94.6586              46.2703
# 2022-09-04 08:00:00.200          15.1106       94.6586              46.5054
#
#                          CH4 Thermocouple Input 1  CH4 Thermocouple Input 2  \
# 2022-09-04 08:00:00.000                   9999.99                   9999.99
# 2022-09-04 08:00:00.050                   9999.99                   9999.99
# 2022-09-04 08:00:00.100                   9999.99                   9999.99
# 2022-09-04 08:00:00.150                   9999.99                   9999.99
# 2022-09-04 08:00:00.200                   9999.99                   9999.99
#
#                          CH4 Thermocouple Input 3  CH4 Diagnostic Value  \
# 2022-09-04 08:00:00.000                   9999.99                    15
# 2022-09-04 08:00:00.050                   9999.99                    15
# 2022-09-04 08:00:00.100                   9999.99                    15
# 2022-09-04 08:00:00.150                   9999.99                    15
# 2022-09-04 08:00:00.200                   9999.99                    15
#
#                          CH4 Drop Rate (%)  CHK
# 2022-09-04 08:00:00.000                  0   79
# 2022-09-04 08:00:00.050                  0   94
# 2022-09-04 08:00:00.100                  0   35
# 2022-09-04 08:00:00.150                  0   22
# 2022-09-04 08:00:00.200                  0  108
#
# [5 rows x 53 columns]
# biomet.data  file:
#
#                     DATAH        DATE          TIME  ALB_1_1_1(other)  \
# 2022-09-04 08:00:00  DATA  2022-09-04  08:00:00:000          0.091674
# 2022-09-04 08:01:00  DATA  2022-09-04  08:01:00:000          0.091587
# 2022-09-04 08:02:00  DATA  2022-09-04  08:02:00:000          0.090633
# 2022-09-04 08:03:00  DATA  2022-09-04  08:03:00:000          0.089990
# 2022-09-04 08:04:00  DATA  2022-09-04  08:04:00:000          0.090156
#
#                      CHK__1_1_1(other)  DAQM_T_1_1_1(C)  DAQM_V_1_1_1(V)  \
# 2022-09-04 08:00:00                 68          17.5547          12.3005
# 2022-09-04 08:01:00                233          17.5859          12.3005
# 2022-09-04 08:02:00                104          17.6250          12.3001
# 2022-09-04 08:03:00                  2          17.6641          12.3001
# 2022-09-04 08:04:00                 63          17.7031          12.3002
#
#                      DRM_POWER_STATUS_1_1_1(other)  DRM_V_BATTERY_1_1_1(V)  \
# 2022-09-04 08:00:00                             15                 12.5237
# 2022-09-04 08:01:00                             15                 12.5237
# 2022-09-04 08:02:00                             15                 12.5197
# 2022-09-04 08:03:00                             15                 12.5197
# 2022-09-04 08:04:00                             15                 12.5237
#
#                      DRM_V_MAIN_1_1_1(V)  ...  RH_1_1_1(%)  RN_1_1_1(W/m^2)  \
# 2022-09-04 08:00:00              28.9327  ...      76.9339          211.160
# 2022-09-04 08:01:00              28.8958  ...      76.8396          213.574
# 2022-09-04 08:02:00              28.8774  ...      76.1419          217.716
# 2022-09-04 08:03:00              28.8958  ...      74.9796          220.218
# 2022-09-04 08:04:00              28.9143  ...      75.8195          221.413
#
#                      SWIN_1_1_1(W/m^2)  SWOUT_1_1_1(W/m^2)  TA_1_1_1(C)  \
# 2022-09-04 08:00:00            309.961             28.4153      14.5316
# 2022-09-04 08:01:00            312.525             28.6230      14.5905
# 2022-09-04 08:02:00            316.707             28.7035      14.6262
# 2022-09-04 08:03:00            319.102             28.7160      14.6341
# 2022-09-04 08:04:00            320.678             28.9110      14.6564
#
#                      TCNR4_C_1_1_1(C)  TS_1_1_1(C)  TS_2_1_1(C)  TS_3_1_1(C)  \
# 2022-09-04 08:00:00           14.7825     -97.0011     -45.8041     -120.846
# 2022-09-04 08:01:00           14.8263     -96.3042     -46.3030     -120.863
# 2022-09-04 08:02:00           14.8669     -96.7418     -46.6877     -120.844
# 2022-09-04 08:03:00           14.9043     -97.2386     -47.0164     -120.858
# 2022-09-04 08:04:00           14.9453     -97.4665     -47.3208     -120.857
#
#                      CHK
# 2022-09-04 08:00:00  201
# 2022-09-04 08:01:00  147
# 2022-09-04 08:02:00   19
# 2022-09-04 08:03:00   69
# 2022-09-04 08:04:00  189
#
# [5 rows x 24 columns]
